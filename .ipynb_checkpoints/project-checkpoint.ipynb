# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import r2_score, mean_squared_error
import numpy as np 
from sklearn.ensemble import RandomForestRegressor
from  sklearn.tree import DecisionTreeRegressor

# %%
pd.options.mode.chained_assignment = None # avoid wanings
df = pd.read_csv("dataset.csv",low_memory=False)
df.head()
# Out:
#   stn_code       sampling_date           state   location agency  \
# 0      150  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 1      151  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 2      152  February - M021990  Andhra Pradesh  Hyderabad    NaN
# 3      150     March - M031990  Andhra Pradesh  Hyderabad    NaN
# 4      151     March - M031990  Andhra Pradesh  Hyderabad    NaN
#
#                                  type  so2   no2  rspm  spm  \
# 0  Residential, Rural and other Areas  4.8  17.4   NaN  NaN
# 1                     Industrial Area  3.1   7.0   NaN  NaN
# 2  Residential, Rural and other Areas  6.2  28.5   NaN  NaN
# 3  Residential, Rural and other Areas  6.3  14.7   NaN  NaN
# 4                     Industrial Area  4.7   7.5   NaN  NaN
#
#   location_monitoring_station  pm2_5      date
# 0                         NaN    NaN  2/1/1990
# 1                         NaN    NaN  2/1/1990
# 2                         NaN    NaN  2/1/1990
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435742 entries, 0 to 435741
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   stn_code                     291665 non-null  object
#  1   sampling_date                435739 non-null  object
#  2   state                        435742 non-null  object
#  3   location                     435739 non-null  object
#  4   agency                       286261 non-null  object
#  5   type                         430349 non-null  object
#  6   so2                          401096 non-null  float64
#  7   no2                          419509 non-null  float64
#  8   rspm                         395520 non-null  float64
#  9   spm                          198355 non-null  float64
#  10  location_monitoring_station  408251 non-null  object
#  11  pm2_5                        9314 non-null    float64
# ...

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm        pm2_5
# count  401096.000000  419509.000000  395520.000000  198355.000000  9314.000000
# mean       10.829414      25.809623     108.832784     220.783480    40.791467
# std        11.177187      18.503086      74.872430     151.395457    30.832525
# min         0.000000       0.000000       0.000000       0.000000     3.000000
# 25%         5.000000      14.000000      56.000000     111.000000    24.000000
# 50%         8.000000      22.000000      90.000000     187.000000    32.000000
# 75%        13.700000      32.200000     142.000000     296.000000    46.000000
# max       909.000000     876.000000    6307.033333    3380.000000   504.000000

# %% [markdown]
# <h1>columns</h1>

# %%
df.columns
# Out:
# Index(['stn_code', 'sampling_date', 'state', 'location', 'agency', 'type',
#        'so2', 'no2', 'rspm', 'spm', 'location_monitoring_station', 'pm2_5',
#        'date'],
#       dtype='object')

# %% [markdown]
# <h1>data types</h1>

# %%
df.dtypes
# Out:
# stn_code                        object
# sampling_date                   object
# state                           object
# location                        object
# agency                          object
# type                            object
# so2                            float64
# no2                            float64
# rspm                           float64
# spm                            float64
# location_monitoring_station     object
# pm2_5                          float64
# date                            object
# dtype: object

# %%
df.state.unique()
# Out:
# array(['Andhra Pradesh', 'Arunachal Pradesh', 'Assam', 'Bihar',
#        'Chandigarh', 'Chhattisgarh', 'Dadra & Nagar Haveli',
#        'Daman & Diu', 'Delhi', 'Goa', 'Gujarat', 'Haryana',
#        'Himachal Pradesh', 'Jammu & Kashmir', 'Jharkhand', 'Karnataka',
#        'Kerala', 'Madhya Pradesh', 'Maharashtra', 'Manipur', 'Meghalaya',
#        'Mizoram', 'Nagaland', 'Odisha', 'Puducherry', 'Punjab',
#        'Rajasthan', 'Sikkim', 'Tamil Nadu', 'Telangana', 'Uttar Pradesh',
#        'Uttarakhand', 'Uttaranchal', 'West Bengal',
#        'andaman-and-nicobar-islands', 'Lakshadweep', 'Tripura'],
#       dtype=object)

# %%
replacements = {
    'state': {
        r'Uttaranchal': 'Uttarakhand', 
    }
}
df.replace(replacements, regex = True, inplace = True)
df["state"].value_counts()
# Out:
# state
# Maharashtra                    60384
# Uttar Pradesh                  42816
# Andhra Pradesh                 26368
# Punjab                         25634
# Rajasthan                      25589
# Kerala                         24728
# Himachal Pradesh               22896
# West Bengal                    22463
# Gujarat                        21279
# Tamil Nadu                     20597
# Madhya Pradesh                 19920
# Assam                          19361
# Odisha                         19279
# Karnataka                      17119
# Delhi                           8551
# Chandigarh                      8520
# Chhattisgarh                    7831
# Goa                             6206
# Jharkhand                       5968
# Mizoram                         5338
# Telangana                       3978
# Meghalaya                       3853
# Puducherry                      3785
# Haryana                         3420
# Nagaland                        2463
# ...

# %%
#value count of agency
df['agency'].value_counts()
# Out:
# agency
# Maharashtra State Pollution Control Board                                 27857
# Uttar Pradesh State Pollution Control Board                               22686
# Andhra Pradesh State Pollution Control Board                              19139
# Himachal Pradesh State Environment Proection & Pollution Control Board    15287
# Punjab State Pollution Control Board                                      15232
#                                                                           ...
# Arunachal Pradesh State Pollution Control Board                              90
# TNPC                                                                         82
# RPCB                                                                         63
# VRCE                                                                         61
# RJPB                                                                         53
# Name: count, Length: 64, dtype: int64

# %%
#deleting all null values of "type", "location", "so2" columns
df = df.dropna(axis=0,subset=['type'])
df = df.dropna(axis = 0, subset = ['location'])
df = df.dropna(axis = 0, subset = ['so2'])

# %%
df.isnull().sum()
# Out:
# stn_code                       119813
# sampling_date                       0
# state                               0
# location                            0
# agency                         125169
# type                                0
# so2                                 0
# no2                              1981
# rspm                            29643
# spm                            228178
# location_monitoring_station     20567
# pm2_5                          386966
# date                                4
# dtype: int64

# %% [markdown]
# <h3>deleting columns that are not required</h3>

# %%
#

del df['agency']
del df['location_monitoring_station']
del df['stn_code']
del df['sampling_date']

# %%
df['type'].value_counts()
# Out:
# type
# Residential, Rural and other Areas    173027
# Industrial Area                        92414
# Residential and others                 70882
# Industrial Areas                       44823
# Sensitive Area                          8856
# Sensitive Areas                         4108
# RIRUO                                   1304
# Sensitive                                456
# Industrial                               183
# Residential                              108
# Name: count, dtype: int64

# %%
#changing type to only 3 categories
a = list(df['type'])
for i in range(0, len(df)):
    if str(a[i][0]) == 'R' and a[i][1] == 'e':
        a[i] = 'Residential'
    elif str(a[i][0]) == 'I':
        a[i] = 'Industrial'
    else:
        a[i] = 'Other'
#the above code takes all the different types and changes them into 3 types( RESIDENTIAL, INDUSTRIAL, OTHER )
df['type'] = a
df['type'].value_counts()
# Out:
# type
# Residential    244017
# Industrial     137420
# Other           14724
# Name: count, dtype: int64

# %% [markdown]
# # **Visulization**

# %% [markdown]
# <h3>plot for 'type'</h3>

# %%
g=sns.catplot( y="type", kind = "count", palette = "pastel", data = df,  orient="h")
g.set_axis_labels("Count","Type Of Area")
# Out:
# /tmp/ipykernel_278434/2493971789.py:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   g=sns.catplot( y="type", kind = "count", palette = "pastel", data = df,  orient="h")

# %% [markdown]
# <h4>frequency of categories in 'types'</h4>

# %%
counts = df["type"].value_counts()
percent = df["type"].value_counts(normalize=True)
percent100 = df["type"].value_counts(normalize=True).mul(100).round(1).astype(str) + '%'
count_df = pd.DataFrame({'counts': counts, 'per': percent, 'per100': percent100})
count_df.info()
count_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3 entries, Residential to Other
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   counts  3 non-null      int64
#  1   per     3 non-null      float64
#  2   per100  3 non-null      object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 96.0+ bytes
#              counts       per per100
# type
# Residential  244017  0.615954  61.6%
# Industrial   137420  0.346879  34.7%
# Other         14724  0.037167   3.7%

# %% [markdown]
# <h3>Pie Chart for 'type'</h3>

# %%
# Pie chart
labels = ['Residential','Industrial','Other']
#colors
colors = ['#ff9999','#66b3ff','#99ff99']
explode = (0.02, 0.02, 0.1)
fig1, ax1 = plt.subplots()
ax1.pie(count_df.per, colors = colors, labels=labels,explode=explode ,autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  
plt.tight_layout()
plt.show()

# %% [markdown]
# <h3>Filling remaining nulls using state-wise averages</h3>

# %%
grp_state = df.groupby('state')
def impute_mean_by_state(series):
    return series.fillna(series.mean())

df['rspm']=grp_state['rspm'].transform(impute_mean_by_state)
df['so2']=grp_state['so2'].transform(impute_mean_by_state)
df['no2']=grp_state['no2'].transform(impute_mean_by_state)
df['spm']=grp_state['spm'].transform(impute_mean_by_state)
df['pm2_5']=grp_state['pm2_5'].transform(impute_mean_by_state)
df.describe()
# Out:
#                  so2            no2           rspm            spm  \
# count  396161.000000  396161.000000  396161.000000  392147.000000
# mean       10.758950      26.156639     111.300928     218.117678
# std        11.116237      18.462806      73.513325     117.066880
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     151.000000
# 50%         8.000000      22.000000      94.000000     207.595198
# 75%        13.500000      32.800000     145.000000     251.000000
# max       909.000000     876.000000    6307.033333    2610.000000
#
#                pm2_5
# count  112271.000000
# mean       48.295883
# std        21.715138
# min         3.000000
# 25%        30.511628
# 50%        42.204089
# 75%        64.979624
# max       504.000000

# %% [markdown]
# <h3>SO<sub>2</sub> median state-wise</h3>

# %%
#so2 vs state - desc order
so2 = df[['so2', 'state']].groupby(['state']).median().sort_values("so2", ascending = False)
ax = sns.catplot(x="so2", y=so2.head(10).index.tolist(), data=so2.head(10), kind="bar",palette="flare" , height=12)
plt.xticks(rotation=90)
so2
# Out:
# /tmp/ipykernel_278434/1066027740.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.catplot(x="so2", y=so2.head(10).index.tolist(), data=so2.head(10), kind="bar",palette="flare" , height=12)
#                             so2
# state
# Uttarakhand           25.000000
# Sikkim                19.800000
# Jharkhand             19.000000
# Gujarat               14.300000
# Maharashtra           14.000000
# Chhattisgarh          12.700000
# Bihar                 11.000000
# Haryana               10.800000
# Madhya Pradesh        10.700000
# Tamil Nadu            10.000000
# Punjab                10.000000
# Uttar Pradesh          9.100000
# Karnataka              8.700000
# Dadra & Nagar Haveli   8.600000
# West Bengal            7.900000
# Daman & Diu            7.600000
# Puducherry             7.000000
# ...

# %% [markdown]
# <h3>NO<sub>2</sub> median state-wise</h3>

# %%
no2 = df[['no2', 'state']].groupby(['state']).median().sort_values("no2", ascending = False)
ax = sns.catplot(x="no2", y=no2.head(10).index.tolist(), data=no2.head(10),palette="flare", kind="bar" , height=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_278434/2592757054.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.catplot(x="no2", y=no2.head(10).index.tolist(), data=no2.head(10),palette="flare", kind="bar" , height=12)

# %% [markdown]
# <h3>PM<sub>10</sub> median state-wise</h3>

# %%
PM10 = df[['rspm', 'state']].groupby(['state']).median().sort_values("rspm", ascending = False)
ax = sns.catplot(x="rspm", y=PM10.head(10).index.tolist(), data=PM10.head(10), palette="flare", kind="bar", height=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_278434/2467701314.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.catplot(x="rspm", y=PM10.head(10).index.tolist(), data=PM10.head(10), palette="flare", kind="bar", height=12)

# %% [markdown]
# <h3>SPM median state-wise</h3>

# %%
spm=df[['spm', 'state']].groupby(['state']).median().sort_values("spm", ascending = False)
ax = sns.catplot(x="spm", y=spm.head(10).index.tolist(), data=spm.head(10), kind="bar",palette="flare" , height=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_278434/1231567835.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.catplot(x="spm", y=spm.head(10).index.tolist(), data=spm.head(10), kind="bar",palette="flare" , height=12)

# %% [markdown]
# <h3>PM<sub>2.5</sub> median state-wise</h3>

# %%
pm2_5=df[['pm2_5', 'state']].groupby(['state']).median().sort_values("pm2_5", ascending = False).head(10)
ax = sns.catplot(x="pm2_5", y=pm2_5.head(10).index.tolist(), data=pm2_5.head(10), kind="bar",palette="flare" , height=12)
plt.xticks(rotation=90)
plt.show()
# Out:
# /tmp/ipykernel_278434/4227487297.py:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.catplot(x="pm2_5", y=pm2_5.head(10).index.tolist(), data=pm2_5.head(10), kind="bar",palette="flare" , height=12)

# %% [markdown]
# <h3>pairplot of 'so2', 'no2', 'rspm', 'spm', 'pm2_5'</h3>

# %%
cols = ['so2', 'no2', 'rspm', 'spm', 'pm2_5']
sns.pairplot(df[cols],height = 2.5)
plt.show()

# %% [markdown]
# <h3>correlation matrix</h3>

# %%
corr_mat = df[cols].corr()
f, ax = plt.subplots(figsize = (10, 5))
sns.heatmap(corr_mat, vmax = 1, square = True, annot = True)
# Out:
# <Axes: >

# %% [markdown]
# ### Creating an year column

# %%
df['date'] = pd.to_datetime(df['date'], format = '%m/%d/%Y')
df['year'] = df['date'].dt.year # year
df['year'] = df['year'].fillna(0.0).astype(int)
df = df[(df['year']>0)]
df.head()
# Out:
#             state   location         type  so2   no2      rspm         spm  \
# 0  Andhra Pradesh  Hyderabad  Residential  4.8  17.4  78.20071  202.379112
# 1  Andhra Pradesh  Hyderabad   Industrial  3.1   7.0  78.20071  202.379112
# 2  Andhra Pradesh  Hyderabad  Residential  6.2  28.5  78.20071  202.379112
# 3  Andhra Pradesh  Hyderabad  Residential  6.3  14.7  78.20071  202.379112
# 4  Andhra Pradesh  Hyderabad   Industrial  4.7   7.5  78.20071  202.379112
#
#    pm2_5       date  year
# 0    NaN 1990-02-01  1990
# 1    NaN 1990-02-01  1990
# 2    NaN 1990-02-01  1990
# 3    NaN 1990-03-01  1990
# 4    NaN 1990-03-01  1990

# %% [markdown]
# ### Heatmap Pivot with State as Row, Year as Col, **No2** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('no2'))
sns.heatmap(df.pivot_table(
        'no2',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'no2 by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# ### Heatmap Pivot with State as Row, Year as Col, **rspm** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('rspm'))
sns.heatmap(df.pivot_table(
        'rspm',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'rspm by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# ### Heatmap Pivot with State as Row, Year as Col, **spm** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('spm'))
sns.heatmap(df.pivot_table(
        'spm',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'spm by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# ### Heatmap Pivot with State as Row, Year as Col, **pm2_5** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('pm2_5'))
sns.heatmap(df.pivot_table(
        'pm2_5',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'pm2_5 by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# ### Heatmap Pivot with State as Row, Year as Col, **so2** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('so2'))
sns.heatmap(df.pivot_table(
        'so2',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'so2 by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# # **Calculating AQI**

# %%
df.describe()
# Out:
#                  so2            no2           rspm            spm  \
# count  396157.000000  396157.000000  396157.000000  392143.000000
# mean       10.758963      26.156681     111.301259     218.117961
# min         0.000000       0.000000       0.000000       0.000000
# 25%         5.000000      14.000000      59.000000     151.000000
# 50%         8.000000      22.000000      94.000000     207.595198
# 75%        13.500000      32.800000     145.000000     251.000000
# max       909.000000     876.000000    6307.033333    2610.000000
# std        11.116290      18.462851      73.513550     117.067431
#
#                pm2_5                           date           year
# count  112270.000000                         396157  396157.000000
# mean       48.295937  2010-05-13 18:33:40.271761152    2009.869216
# min         3.000000            1987-01-01 00:00:00    1987.000000
# 25%        30.511628            2007-11-05 00:00:00    2007.000000
# ...

# %%
# defining calculation functions

def cal_SO2i(so2):
    si=0
    if (so2<=40):
     si= so2*(50/40)
    elif (so2>40 and so2<=80):
     si= 50+(so2-40)*(50/40)
    elif (so2>80 and so2<=380):
     si= 100+(so2-80)*(100/300)
    elif (so2>380 and so2<=800):
     si= 200+(so2-380)*(100/420)
    elif (so2>800 and so2<=1600):
     si= 300+(so2-800)*(100/800)
    elif (so2>1600):
     si= 400+(so2-1600)*(100/800)
    return si
    
def cal_Noi(no2):
    ni=0
    if(no2<=40):
     ni= no2*50/40
    elif(no2>40 and no2<=80):
     ni= 50+(no2-40)*(50/40)
    elif(no2>80 and no2<=180):
     ni= 100+(no2-80)*(100/100)
    elif(no2>180 and no2<=280):
     ni= 200+(no2-180)*(100/100)
    elif(no2>280 and no2<=400):
     ni= 300+(no2-280)*(100/120)
    else:
     ni= 400+(no2-400)*(100/120)
    return ni
    
def cal_RSPMi(rspm):
    rpi=0
    if(rspm<=100):
     rpi = rspm
    elif(rspm>=101 and rspm<=150):
     rpi= 101+(rspm-101)*((200-101)/(150-101))
    elif(rspm>=151 and rspm<=350):
     ni= 201+(rspm-151)*((300-201)/(350-151))
    elif(rspm>=351 and rspm<=420):
     ni= 301+(rspm-351)*((400-301)/(420-351))
    elif(rspm>420):
     ni= 401+(rspm-420)*((500-401)/(420-351))
    return rpi

def cal_SPMi(spm):
    spi=0
    if(spm<=50):
     spi=spm*50/50
    elif(spm>50 and spm<=100):
     spi=50+(spm-50)*(50/50)
    elif(spm>100 and spm<=250):
     spi= 100+(spm-100)*(100/150)
    elif(spm>250 and spm<=350):
     spi=200+(spm-250)*(100/100)
    elif(spm>350 and spm<=430):
     spi=300+(spm-350)*(100/80)
    else:
     spi=400+(spm-430)*(100/430)
    return spi

def cal_PM2_5i(pm2_5):
    pmi=0
    if(pm2_5<=50):
     pmi=pm2_5*(50/50)
    elif(pm2_5>50 and pm2_5<=100):
     pmi=50+(pm2_5-50)*(50/50)
    elif(pm2_5>100 and pm2_5<=250):
     pmi= 100+(pm2_5-100)*(100/150)
    elif(pm2_5>250 and pm2_5<=350):
     pmi=200+(pm2_5-250)*(100/100)
    elif(pm2_5>350 and pm2_5<=450):
     pmi=300+(pm2_5-350)*(100/100)
    else:
     pmi=400+(pm2_5-430)*(100/80)
    return pmi

df['SO2i']   =   df['so2'].apply(cal_SO2i)
df['Noi']    =   df['no2'].apply(cal_Noi)
df['RSPMi']  =   df['rspm'].apply(cal_RSPMi)
df['SPMi']   =   df['spm'].apply(cal_SPMi)
df['PM2_5i'] =   df['pm2_5'].apply(cal_PM2_5i)
df.head()
# Out:
#             state   location         type  so2   no2      rspm         spm  \
# 0  Andhra Pradesh  Hyderabad  Residential  4.8  17.4  78.20071  202.379112
# 1  Andhra Pradesh  Hyderabad   Industrial  3.1   7.0  78.20071  202.379112
# 2  Andhra Pradesh  Hyderabad  Residential  6.2  28.5  78.20071  202.379112
# 3  Andhra Pradesh  Hyderabad  Residential  6.3  14.7  78.20071  202.379112
# 4  Andhra Pradesh  Hyderabad   Industrial  4.7   7.5  78.20071  202.379112
#
#    pm2_5       date  year   SO2i     Noi     RSPMi        SPMi  PM2_5i
# 0    NaN 1990-02-01  1990  6.000  21.750  78.20071  168.252741     NaN
# 1    NaN 1990-02-01  1990  3.875   8.750  78.20071  168.252741     NaN
# 2    NaN 1990-02-01  1990  7.750  35.625  78.20071  168.252741     NaN
# 3    NaN 1990-03-01  1990  7.875  18.375  78.20071  168.252741     NaN
# 4    NaN 1990-03-01  1990  5.875   9.375  78.20071  168.252741     NaN

# %% [markdown]
# ### removing null values

# %%
df=df.dropna(subset=['spm']) #spm
df=df.dropna(subset=['pm2_5']) #spm
df.isna().sum() #all null values removed
# Out:
# state       0
# location    0
# type        0
# so2         0
# no2         0
# rspm        0
# spm         0
# pm2_5       0
# date        0
# year        0
# SO2i        0
# Noi         0
# RSPMi       0
# SPMi        0
# PM2_5i      0
# dtype: int64

# %%
# AQI function
def cal_aqi(si,ni,rspmi,spmi,pmi):
    aqi=0
    if(si>ni and si>rspmi and si>spmi):
     aqi=si
    if(ni>si and ni>rspmi and ni>spmi ):
     aqi=ni
    if(rspmi>si and rspmi>ni and rspmi>spmi ):
     aqi=rspmi
    if(spmi>si and spmi>ni and spmi>rspmi):
     aqi=spmi
    return aqi

# %%
df['AQI']=df.apply(lambda x:cal_aqi(x['SO2i'],x['Noi'],x['RSPMi'],x['SPMi'],x['PM2_5i']),axis=1)
df = df[['state','year','type','Noi','SO2i','RSPMi','SPMi','PM2_5i','AQI']]
df.head()
# Out:
#                       state  year        type     Noi    SO2i       RSPMi  \
# 64476  Dadra & Nagar Haveli  2007  Industrial  23.125  13.000  111.102041
# 64477  Dadra & Nagar Haveli  2007  Industrial  23.625  13.375  121.204082
# 64478  Dadra & Nagar Haveli  2007  Industrial  23.625  13.375  121.204082
# 64479  Dadra & Nagar Haveli  2007  Industrial  24.250  13.625   95.000000
# 64480  Dadra & Nagar Haveli  2007  Industrial  24.500  13.750  127.265306
#
#              SPMi     PM2_5i         AQI
# 64476  200.000000  30.511628  200.000000
# 64477  211.000000  30.511628  211.000000
# 64478  210.000000  30.511628  210.000000
# 64479  181.333333  30.511628  181.333333
# 64480  214.000000  30.511628  214.000000

# %%
def AQI_Range(x):
    if x<=50:
        return "Good"
    elif x>50 and x<=100:
        return "Moderate"
    elif x>100 and x<=200:
        return "Poor"
    elif x>200 and x<=300:
        return "Unhealthy"
    elif x>300 and x<=400:
        return "Very unhealthy"
    elif x>400:
        return "Hazardous"

# %%
df['AQI_Range'] = df['AQI'] .apply(AQI_Range)
df.head()
# Out:
#                       state  year        type     Noi    SO2i       RSPMi  \
# 64476  Dadra & Nagar Haveli  2007  Industrial  23.125  13.000  111.102041
# 64477  Dadra & Nagar Haveli  2007  Industrial  23.625  13.375  121.204082
# 64478  Dadra & Nagar Haveli  2007  Industrial  23.625  13.375  121.204082
# 64479  Dadra & Nagar Haveli  2007  Industrial  24.250  13.625   95.000000
# 64480  Dadra & Nagar Haveli  2007  Industrial  24.500  13.750  127.265306
#
#              SPMi     PM2_5i         AQI  AQI_Range
# 64476  200.000000  30.511628  200.000000       Poor
# 64477  211.000000  30.511628  211.000000  Unhealthy
# 64478  210.000000  30.511628  210.000000  Unhealthy
# 64479  181.333333  30.511628  181.333333       Poor
# 64480  214.000000  30.511628  214.000000  Unhealthy

# %% [markdown]
# ### Heatmap Pivot with **state** as Row, **year** as Col, **AQI** median as Value

# %%
f, ax = plt.subplots(figsize=(15,15))
ax.set_title('{} by state and year'.format('AQI'))
sns.heatmap(df.pivot_table(
        'AQI',
        index='state',
        columns=['year'],
        aggfunc='median',
        margins=True
    ),
    fmt=".0f",
    annot = True,
    cmap = "YlGnBu",
    linewidths = 1,
    ax = ax,
    cbar_kws = {'label': 'Annual Average'}           
)
# Out:
# <Axes: title={'center': 'AQI by state and year'}, xlabel='year', ylabel='state'>

# %% [markdown]
# # Model Creation

# %%
df.columns
# Out:
# Index(['state', 'year', 'type', 'Noi', 'SO2i', 'RSPMi', 'SPMi', 'PM2_5i',
#        'AQI', 'AQI_Range'],
#       dtype='object')

# %%
X = df[['SO2i','Noi','RSPMi','SPMi','PM2_5i']]
Y = df['AQI']
X.head(3)
# Out:
#          SO2i     Noi       RSPMi   SPMi     PM2_5i
# 64476  13.000  23.125  111.102041  200.0  30.511628
# 64477  13.375  23.625  121.204082  211.0  30.511628
# 64478  13.375  23.625  121.204082  210.0  30.511628

# %%
X_train, X_test, y_train, y_test = train_test_split(X,Y, test_size=0.2,random_state=42)

# %%
X.columns
# Out:
# Index(['SO2i', 'Noi', 'RSPMi', 'SPMi', 'PM2_5i'], dtype='object')

# %% [markdown]
# ## Linear Regression

# %%
model = LinearRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print(f'Intercept: {model.intercept_}')
print(f"Coefficient: {model.coef_}")
# Out:
# Intercept: 5.396529211015377
# Coefficient: [ 0.01757372  0.06998978  0.04981356  0.95480321 -0.02019344]

# %%
y_pred = model.predict(X_test)
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
model.score(X_test,y_test)
# Out:
# 0.9797043010825118

# %%
print('R^2_Square:%.2f '% r2_score(y_test, y_pred))
print('MSE:%.2f '% np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R^2_Square:0.98
# MSE:12.61

# %% [markdown]
# ## Random Forest Regressor

# %%
model_RFR = RandomForestRegressor(n_estimators=100, random_state=42)
model_RFR.fit(X_train, y_train)
# Out:
# RandomForestRegressor(random_state=42)

# %%
y_pred = model_RFR.predict(X_test)
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('R^2_Square:%.2f '% r2_score(y_test, y_pred))
print('MSE:%.2f '% np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R^2_Square:1.00
# MSE:2.08

# %% [markdown]
# ## Decision Tree Regressor

# %%
model_DTR = DecisionTreeRegressor()

# %%
model_DTR.fit(X_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred = model_DTR.predict(X_test)
plt.scatter(y_test,y_pred)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
print('R^2_Square:%.2f '% r2_score(y_test, y_pred))
print('MSE:%.2f '% np.sqrt(mean_squared_error(y_test, y_pred)))
# Out:
# R^2_Square:1.00
# MSE:2.97
